# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from solar_forecast.clearsky import get_clearsky
from solar_forecast.fetch_nwp import fetch_nwp

# %%
times = pd.date_range("2024-07-15", periods=24, freq="1h", tz="Europe/Vienna")

# %%
df = get_clearsky(lat=47.5, lon=14.5, times=times)

# %%
print(df)

# %%
nwp = fetch_nwp(lat=47.5, lon=14.5, forecast_days=2)

print("Variables available:", list(nwp.keys()))
print("Shape:", nwp["shortwave_radiation"].shape)
print(nwp["shortwave_radiation"].head(30))
