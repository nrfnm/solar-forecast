# %%
from solar_forecast import clearsky
import pandas as pd

# %%
times = pd.date_range("2024-07-15", periods=24, freq="1h", tz="Europe/Vienna")

# %%
df = clearsky.get_clearsky(lat=47.5, lon=14.5, times=times)

# %%
print(df)
# Out:
#                                   ghi         dni         dhi  \
# 2024-07-15 00:00:00+02:00    0.000000    0.000000    0.000000
# 2024-07-15 01:00:00+02:00    0.000000    0.000000    0.000000
# 2024-07-15 02:00:00+02:00    0.000000    0.000000    0.000000
# 2024-07-15 03:00:00+02:00    0.000000    0.000000    0.000000
# 2024-07-15 04:00:00+02:00    0.000000    0.000000    0.000000
# 2024-07-15 05:00:00+02:00    0.000000    0.000000    0.000000
# 2024-07-15 06:00:00+02:00   21.905285  102.318855   12.870695
# 2024-07-15 07:00:00+02:00  159.849718  438.177428   50.982629
# 2024-07-15 08:00:00+02:00  335.302357  628.852197   76.645383
# 2024-07-15 09:00:00+02:00  508.819243  732.485270   95.109258
# 2024-07-15 10:00:00+02:00  662.299539  792.354889  109.009676
# 2024-07-15 11:00:00+02:00  783.151116  827.418010  119.058915
# 2024-07-15 12:00:00+02:00  862.235878  846.386147  125.344917
# 2024-07-15 13:00:00+02:00  893.758752  853.242103  127.799569
# ...
